# %%
import numpy as np
from filterpy.kalman import KalmanFilter
import pandas as pd
import matplotlib.pyplot as plt
from scipy.optimize import minimize
import scipy.stats as sa
import scipy.linalg as la

# %%
df = pd.read_csv("Cleaned Datasets/US_Full_Quarterly.csv")

# %%
class OurKalmanFilter:
    def __init__(self, df, y, var1="Diff Log Dependency", var2="Diff Log Inv", yearSplit=2000, dim_x=1, dim_z = 1):
        self.yearSplit = yearSplit
        self.dim_x = dim_x
        self.dim_z = dim_z
        self.df = df.copy()
        self.y = y
        self._formatData(var1, var2)
        self.var1 = var1
        self.var2 = var2

    def _formatData(self, var1="Diff Log Dependency", var2="Diff Log Inv"):
        self.df["Log GDP"] = np.log(self.df["GDP"])
        self.df['Diff Log GDP'] = self.df['Log GDP'] - self.df['Log GDP'].shift(1)
        self.df["Log Inv"] = np.log(self.df["Inv"])
        self.df["Diff Log Inv"] = self.df["Log Inv"] - self.df["Log Inv"].shift(1)
        self.df["Log Dependency"] = np.log(self.df["Dependency"])
        for i in range(1,4):
            self.df["Log Dependency"]+= np.log(self.df["Dependency"].shift(i))
        self.df["Log Dependency"] /= 4

        self.df["Diff Log Dependency"] = self.df["Log Dependency"] - self.df["Log Dependency"].shift(4)

        deflator = pd.read_csv("Cleaned Datasets/GDPDEF.csv",index_col = "DATE")
        self.df = self.df.join(deflator,on = "DATE", how = "inner")
        self.df["Real GDP"] = self.df["GDP"]/self.df["GDPDEF"]
        self.df["Real Inv"] = self.df["Inv"]/self.df["GDPDEF"]
        
        self.df.set_index("DATE", drop=True, inplace=True)
        self.df.dropna(inplace=True)

        if self.dim_x == 1:
            self.df = self.df[[self.y]]
        elif self.dim_x == 3:
            self.df = self.df[[self.y, var1, var2]]

        # Split the data into train and test
        self.trainingData = self.df[self.df.index <= str(self.yearSplit)]
        self.testingData = self.df[self.df.index > str(self.yearSplit)]

        if self.dim_z == 1:
            self.zMatrix = self.trainingData[self.y].to_numpy()
        elif self.dim_z == 3:
            self.zMatrix = self.trainingData.to_numpy()

        return None
    
    def train(self, F, H):
        # Set initial parameters
        self.Q = np.eye(self.dim_x)*.1
        self.R = np.eye(self.dim_z)*.1
        df_ = self.df.to_numpy()
        self.x0 = df_[0] 
      
        # The initialization of F and H are really sensitive to initial conditions.
        # It is reasonable to initialize F and H both to 1
        # F = np.eye(self.dim_x).ravel()
        # H = np.ones((self.dim_x, self.dim_z)).ravel()
        X = F.ravel()
        self.H = H.reshape(1,-1)
      
        X = minimize(self._likelihood, X, method="bfgs", tol=1e-8).x
        
        self.F = X.reshape(self.dim_x, self.dim_x)
        print(self.F)
        return None

    def _likelihood(self, X):
        # Unpack the values
        F = X.reshape(self.dim_x, self.dim_x)
    
        
        # Initialize appropriate parameters
        xhat = self.x0.copy()
        Phat = np.eye(self.dim_x)*100
        logLikelis = []
        # Calculate the mean of z
        # mu = np.mean(self.zMatrix)
        mu = 0
        # Calculate the log-likelihood for each point.
        for i in range(self.zMatrix.shape[0]):
            # Predict the x value
            xhat = F@xhat
            
            # Predict the P value
            Phat = F@Phat@(F.T) + self.Q
            mean = self.H@xhat + mu
            cov = self.H@Phat@(self.H.T) +self.R
            likelihood = sa.multivariate_normal.pdf(self.zMatrix[i], mean=mean, cov=cov, allow_singular=True)
            logLikelis.append(likelihood)
            print(likelihood)
            
            result = 1
            for i in range(len(logLikelis)):
                result *= logLikelis[i]
        result()
        return -1*result
    

    def fit_predict(self, stepsForward):
        f = KalmanFilter(dim_x=self.dim_x, dim_z=self.dim_z)
        f.x = self.x0.copy().reshape(-1,1)
        f.F = self.F.copy()
        f.H = self.H.copy()
        f.Q = self.Q.copy()
        f.R = self.R.copy()

        self.xhat, Ps, self.z = self._predict(f, self.zMatrix, stepsForward)
        return None
    
    def _filter(self, f, zs):
        n = np.size(zs,0)
        # initialize
        xhat = np.zeros((n,f.dim_x,1))
        Ps = np.zeros((n,f.dim_x,f.dim_x))
        z_filtered = np.zeros((n,f.dim_z))
    
        for i,z in enumerate(zs):
            f.predict()
            f.update(z)
            xhat[i] = f.x.copy()
            Ps[i] = f.P.copy()
            z_filtered[i] = (f.H)@(xhat[i].reshape(f.dim_x,))
            
        return xhat, Ps, z_filtered

    def _predict(self, f, zs, stepsForward):
        xhat, Ps, z_filtered = self._filter(f, zs)
        xhat_predict = np.zeros((stepsForward, f.dim_x, 1))
        Ps_predict = np.zeros((stepsForward, f.dim_x, f.dim_x))
        z_predicts = np.zeros((stepsForward, f.dim_z))

        for i in range(stepsForward):
            f.predict()
            xhat_predict[i] = f.x.copy()
            Ps[i] = f.P.copy()
            z_predicts[i] = (f.H)@(xhat_predict[i].reshape(f.dim_x,))
        
        # TODO: We could also alter the function so that it saves the filtered and predicts separately
        return np.vstack((xhat, xhat_predict)), 0, np.vstack((z_filtered, z_predicts))
    
    def plotResults(self):
        # Plot the results
        self.df.index = pd.to_datetime(self.df.index).to_period(freq="D")
        self.trainingData.index = pd.to_datetime(self.trainingData.index).to_period(freq="D")
        self.testingData.index = pd.to_datetime(self.testingData.index).to_period(freq="D")
        if self.dim_z == 1:
            fig, axs = plt.subplots(1,self.dim_z,figsize=(10,5))
        elif self.dim_z:
            fig, axs = plt.subplots(1,self.dim_z,figsize=(15,5))

    
        def plot_z(given_z, i=None, column = None):
            if i == None:
                self.trainingData.plot(y=self.y, ax=axs, label="Training Data", use_index=True)
                self.testingData.plot(y=self.y, ax=axs, label="Testing Data", use_index=True)
                domain = pd.date_range(start=self.df.index[0].to_timestamp(), periods=given_z.size, freq="QS")
                axs.plot(domain, given_z, 'g--', label='filter estimates')

                # Manually set x-axis tick marks and labels for every 10 years
                start_date = pd.Timestamp(self.df.index.min().year, 1, 1).to_period(freq="D")
                end_date = pd.Timestamp(self.df.index.max().year, 1, 1).to_period(freq="D")
                tick_positions = pd.date_range(start=start_date.to_timestamp(), end=end_date.to_timestamp(), freq='10AS')
                tick_labels = [tick.strftime('%Y') for tick in tick_positions]
                axs.set_xticks(tick_positions, tick_labels)
                axs.set_title(self.y)
                axs.legend()
            else:
                self.trainingData.plot(y=column, ax=axs[i], label="Training Data", use_index=True)
                self.testingData.plot(y=column, ax=axs[i], label="Testing Data", use_index=True)
                domain = pd.date_range(start=self.df.index[0].to_timestamp(), periods=given_z.size, freq="QS")
                axs[i].plot(domain, given_z, 'g--', label='filter estimates')

                # Manually set x-axis tick marks and labels for every 10 years
                start_date = pd.Timestamp(self.df.index.min().year, 1, 1).to_period(freq="D")
                end_date = pd.Timestamp(self.df.index.max().year, 1, 1).to_period(freq="D")
                tick_positions = pd.date_range(start=start_date.to_timestamp(), end=end_date.to_timestamp(), freq='10AS')
                tick_labels = [tick.strftime('%Y') for tick in tick_positions]
                axs[i].set_xticks(tick_positions, tick_labels)
                axs[i].set_title(column)
                axs[i].legend()

        if self.dim_z == 1:
            plot_z(self.z)
            
        elif self.dim_z == 3:
            plot_z(self.z[:,0], 0, self.y)
            plot_z(self.z[:,1], 1, self.var1)
            plot_z(self.z[:,2], 2, self.var2)
            # domain = pd.date_range(start=self.df.index[0].to_timestamp(), periods=self.z.size, freq="QS")

            # self.df[[self.y]].plot(ax=axs[0], label="Original Data", markersize=2, linestyle='-', color="b")
            # axs[0].plot(domain, self.z[:, 0], 'g--', label='filter estimates')
            # axs[0].set_title(self.y)
            # axs[0].legend()

            # self.df[[self.var1]].plot(ax=axs[1], label="Original Data", markersize=2, linestyle='-', color="b")
            # axs[1].plot(domain, self.z[:, 1], label='filter estimates', color="r")
            # axs[1].set_title(self.var1)
            # axs[1].legend()

            # self.df[[self.var2]].plot(ax=axs[2], color='b', marker='o', label="Original Data", markersize=2, linestyle='none')
            # axs[2].plot(domain, self.z[:, 2], label='filter estimates', color="r")
            # axs[2].set_title(self.var2)
            # axs[2].legend()
        plt.tight_layout()

# %%
test1d = OurKalmanFilter(df, "Real GDP", yearSplit='2010', var1='Dependency', var2="Inv", dim_x=3, dim_z=1)
# F = np.array([[1.1, 0.1, 0.2],   # Influence of past values on consumption expenditure
#               [0.2, 1.1, 0.1],   # Influence of past values on investment expenditure
#               [0.1, 0.2, 1.1]])

F = np.eye(3)*1.003
F[1,1] = 1
# Measurement matrix H
H = np.ones(3)  # We observe the total GDP, which is the sum of the three components
test1d.train(F, H)
test1d.fit_predict(stepsForward=50)
# Out:
# 6.659704959968642e-11
# 8.06595215342752e-11
# 8.701732239425725e-11
# 9.815614232963446e-11
# 9.800583074646048e-11
# 1.0863564595077508e-10
# 1.209485358994702e-10
# 1.5613794296691722e-10
# 1.6330625880786282e-10
# 2.0900267715597087e-10
# 2.3261063859422792e-10
# 2.7689840701061724e-10
# 2.7605351905426885e-10
# 3.720804983140153e-10
# 4.258325681188346e-10
# 5.61109184524398e-10
# 7.506229782434896e-10
# 1.0278431603841283e-09
# 1.0302117158745816e-09
# 1.114834733988093e-09
# 1.2030749584794222e-09
# 1.310332558253879e-09
# 1.2592081760021236e-09
# 1.3851136357751404e-09
# 1.4791991800887946e-09
# 1.9252556279152135e-09
# 2.372994733364312e-09
# 2.5489421176264197e-09
# 2.578473746412501e-09
# 3.1350514839070547e-09
# 3.1278776144821196e-09
# 3.3006435259937183e-09
# 2.9036873276477624e-09
# 2.695461404632216e-09
# 2.6226677372316145e-09
# 2.8844585188871656e-09
# 2.3124317855579267e-09
# 3.3642119989342937e-09
# 3.4850682927186365e-09
# 3.778820774663873e-09
# 3.730127948570116e-09
# 4.751143578436271e-09
# 6.499751109692953e-09
# 7.202309163590438e-09
# 8.985856867636674e-09
# 1.2792130413861674e-08
# 1.4540113672723338e-08
# 1.2645634334351665e-08
# 1.40524748271105e-08
# 1.155098781062578e-08
# 1.1405038034145887e-08
# 9.249614529853643e-09
# 8.236211135261936e-09
# 6.393650601726725e-09
# 6.826604222851416e-09
# 8.580214614471962e-09
# 1.016883992692863e-08
# 1.3994514195208048e-08
# 1.501830700905186e-08
# 1.56238120879701e-08
# 1.6741590055016928e-08
# 1.9382843415282534e-08
# 2.5499315713234468e-08
# 3.2830994628218095e-08
# 3.11379677469767e-08
# 3.120076964042723e-08
# 5.687805910076308e-08
# 6.414168226878312e-08
# 7.675566679222525e-08
# 7.505080681256981e-08
# 7.246464717295895e-08
# 7.814879807746795e-08
# 7.738727355017164e-08
# 7.74758689994925e-08
# 5.1090630946490046e-08
# 4.7458214681635414e-08
# 6.204178672480157e-08
# 8.253551958106367e-08
# 6.86814092775047e-08
# 8.015841959432308e-08
# 6.271715780472345e-08
# 4.526380069725576e-08
# 4.6440456387852546e-08
# 4.11902856439988e-08
# 3.931655713406035e-08
# 4.6780371365980075e-08
# 6.569391795710167e-08
# 8.811237969038221e-08
# 1.2021543747777054e-07
# 1.6050605239984418e-07
# 2.0627175559308031e-07
# 2.318727439894883e-07
# 2.541479432965513e-07
# 2.860457841596488e-07
# 3.1700673600233254e-07
# 3.9407407864125625e-07
# 4.263474869630737e-07
# 4.772506833194171e-07
# 4.900172562803081e-07
# 5.509919002538274e-07
# 5.745780856841435e-07
# 6.216351616817698e-07
# 7.145988295449985e-07
# 7.909436135158388e-07
# 1.0193709844336134e-06
# 1.059861836662664e-06
# 1.2716219518235567e-06
# 1.3383962859130835e-06
# 1.6118508463868738e-06
# 1.8338844057454108e-06
# 1.9933978283009783e-06
# 2.1587316529570496e-06
# 2.1181831429236453e-06
# 2.443526865980285e-06
# 2.4706912784019182e-06
# 2.367941581749489e-06
# 1.8976479138607815e-06
# 1.6493650177840828e-06
# 1.7985324765661514e-06
# 1.8658516471025262e-06
# 1.8820813632356679e-06
# 2.213261188487096e-06
# 2.5500006760076814e-06
# 2.8874566119410216e-06
# 3.3029703452883574e-06
# 3.2229848643907783e-06
# 3.3914846607492746e-06
# 3.5021395861191866e-06
# 4.240928318314677e-06
# 4.786371583201971e-06
# 5.789898974834446e-06
# 6.094605353289138e-06
# 7.099212268670604e-06
# 7.167769081974899e-06
# 7.165777634467598e-06
# 7.913174096358446e-06
# 8.473891020782225e-06
# 9.188521579123634e-06
# 1.1738313310028842e-05
# 1.3063556874682624e-05
# 1.4912873137657354e-05
# 1.5861015355511265e-05
# 2.021887137937188e-05
# 2.392434556335345e-05
# 2.6397283079199565e-05
# 2.989563233781035e-05
# 3.33840449665214e-05
# 3.950718254070646e-05
# 4.963275476577742e-05
# 5.546440969170717e-05
# 6.087351294067551e-05
# 7.264407600233426e-05
# 9.13443227152981e-05
# 9.234259680477782e-05
# 0.00011940096983284256
# 0.00011546795345602645
# 0.00012143433738334146
# 0.00010912231518878244
# 0.00011530116197671152
# 0.00010231040128161207
# 0.00010187015038506272
# 0.00011159856379354447
# 0.00011767161316933046
# 0.00011979731883103256
# 0.0001162683541427919
# 0.0001208287171984471
# 0.0001333530532040357
# 0.00016729899830859508
# 0.0001928818302720787
# 0.00020155638522648914
# 0.00021789560063162583
# 0.00024221603095069523
# 0.0002721702948912084
# 0.0003098788595621143
# 0.00031961817120428044
# 0.00034519019515886617
# 0.00035943962940556345
# 0.00042355132130222103
# 0.0004207842050184497
# 0.00041088027400416313
# 0.0004484282181703994
# 0.000448401574343355
# 0.00047062093849885035
# 0.0004910570476928892
# 0.0005165177666900676
# 0.0004612486983209187
# 0.00048275583886278156
# 0.00042415839642507343
# 0.0002840440614755109
# 0.00022451794651657327
# 0.00020749627673464675
# 0.00020921862856758752
# 0.00023759936355018384
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/wf/8xpx26491r14zr3yp5ckk3yh0000gn/T/ipykernel_59565/1590835545.py in <module>
#       8 # Measurement matrix H
#       9 H = np.ones(3)  # We observe the total GDP, which is the sum of the three components
# ---> 10 test1d.train(F, H)
#      11 test1d.fit_predict(stepsForward=50)
#
# /var/folders/wf/8xpx26491r14zr3yp5ckk3yh0000gn/T/ipykernel_59565/1638724942.py in train(self, F, H)
#      60         self.H = H.reshape(1,-1)
#      61
# ---> 62         X = minimize(self._likelihood, X, method="bfgs", tol=1e-8).x
#      63
#      64         self.F = X.reshape(self.dim_x, self.dim_x)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     689         res = _minimize_cg(fun, x0, args, jac, callback, **options)
#     690     elif meth == 'bfgs':
# --> 691         res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#     692     elif meth == 'newton-cg':
#     693         res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/_optimize.py in _minimize_bfgs(fun, x0, args, jac, callback, gtol, norm, eps, maxiter, disp, return_all, finite_diff_rel_step, xrtol, **unknown_options)
#    1360         maxiter = len(x0) * 200
#    1361
# -> 1362     sf = _prepare_scalar_function(fun, x0, jac, args=args, epsilon=eps,
#    1363                                   finite_diff_rel_step=finite_diff_rel_step)
#    1364
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/_optimize.py in _prepare_scalar_function(fun, x0, jac, args, bounds, epsilon, finite_diff_rel_step, hess)
#     330     # ScalarFunction caches. Reuse of fun(x) during grad
#     331     # calculation reduces overall function evaluations.
# --> 332     sf = ScalarFunction(fun, x0, args, grad, hess,
#     333                         finite_diff_rel_step, bounds, epsilon=epsilon)
#     334
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in __init__(self, fun, x0, args, grad, hess, finite_diff_rel_step, finite_diff_bounds, epsilon)
#     156
#     157         self._update_fun_impl = update_fun
# --> 158         self._update_fun()
#     159
#     160         # Gradient evaluation
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in _update_fun(self)
#     249     def _update_fun(self):
#     250         if not self.f_updated:
# --> 251             self._update_fun_impl()
#     252             self.f_updated = True
#     253
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in update_fun()
#     153
#     154         def update_fun():
# --> 155             self.f = fun_wrapped(self.x)
#     156
#     157         self._update_fun_impl = update_fun
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in fun_wrapped(x)
#     135             # Overwriting results in undefined behaviour because
#     136             # fun(self.x) will change self.x, with the two no longer linked.
# --> 137             fx = fun(np.copy(x), *args)
#     138             # Make sure the function returns a true scalar
#     139             if not np.isscalar(fx):
#
# /var/folders/wf/8xpx26491r14zr3yp5ckk3yh0000gn/T/ipykernel_59565/1638724942.py in _likelihood(self, X)
#      94             for i in range(len(logLikelis)):
#      95                 result *= logLikelis[i]
# ---> 96         result()
#      97         return -1*result
#      98
#
# TypeError: 'numpy.float64' object is not callable

# %%
test1d.plotResults()

# %%
test1d = OurKalmanFilter(df, "Real GDP", yearSplit='2010', var1='Diff Log Dependency', var2="Diff Log Inv", dim_x=3, dim_z=3)
F = np.eye(3)*1.01 # Influence of past values on consumption expenditure
# F = np.array([[0.9, 0.1, 0.2],   # Influence of past values on consumption expenditure
#               [0.2, 0.8, 0.1],   # Influence of past values on investment expenditure
#               [0.1, 0.2, 0.9]])


# Measurement matrix H
H = np.ones((3, 3))  # We observe the total GDP, which is the sum of the three components
test1d.train(F, H)
test1d.fit_predict(stepsForward=50)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/wf/8xpx26491r14zr3yp5ckk3yh0000gn/T/ipykernel_59565/2545149933.py in <module>
#       8 # Measurement matrix H
#       9 H = np.ones((3, 3))  # We observe the total GDP, which is the sum of the three components
# ---> 10 test1d.train(F, H)
#      11 test1d.fit_predict(stepsForward=50)
#
# /var/folders/wf/8xpx26491r14zr3yp5ckk3yh0000gn/T/ipykernel_59565/2240863171.py in train(self, F, H)
#      54         self.H = H.reshape(1,-1)
#      55
# ---> 56         X = minimize(self._likelihood, X, method="bfgs", tol=1e-8).x
#      57
#      58         self.F = X.reshape(self.dim_x, self.dim_x)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     689         res = _minimize_cg(fun, x0, args, jac, callback, **options)
#     690     elif meth == 'bfgs':
# --> 691         res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#     692     elif meth == 'newton-cg':
#     693         res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/_optimize.py in _minimize_bfgs(fun, x0, args, jac, callback, gtol, norm, eps, maxiter, disp, return_all, finite_diff_rel_step, xrtol, **unknown_options)
#    1360         maxiter = len(x0) * 200
#    1361
# -> 1362     sf = _prepare_scalar_function(fun, x0, jac, args=args, epsilon=eps,
#    1363                                   finite_diff_rel_step=finite_diff_rel_step)
#    1364
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/_optimize.py in _prepare_scalar_function(fun, x0, jac, args, bounds, epsilon, finite_diff_rel_step, hess)
#     330     # ScalarFunction caches. Reuse of fun(x) during grad
#     331     # calculation reduces overall function evaluations.
# --> 332     sf = ScalarFunction(fun, x0, args, grad, hess,
#     333                         finite_diff_rel_step, bounds, epsilon=epsilon)
#     334
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in __init__(self, fun, x0, args, grad, hess, finite_diff_rel_step, finite_diff_bounds, epsilon)
#     156
#     157         self._update_fun_impl = update_fun
# --> 158         self._update_fun()
#     159
#     160         # Gradient evaluation
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in _update_fun(self)
#     249     def _update_fun(self):
#     250         if not self.f_updated:
# --> 251             self._update_fun_impl()
#     252             self.f_updated = True
#     253
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in update_fun()
#     153
#     154         def update_fun():
# --> 155             self.f = fun_wrapped(self.x)
#     156
#     157         self._update_fun_impl = update_fun
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in fun_wrapped(x)
#     135             # Overwriting results in undefined behaviour because
#     136             # fun(self.x) will change self.x, with the two no longer linked.
# --> 137             fx = fun(np.copy(x), *args)
#     138             # Make sure the function returns a true scalar
#     139             if not np.isscalar(fx):
#
# /var/folders/wf/8xpx26491r14zr3yp5ckk3yh0000gn/T/ipykernel_59565/2240863171.py in _likelihood(self, X)
#      78             # Predict the P value
#      79             Phat = F@Phat@(F.T) + self.Q
# ---> 80             mean = self.H@xhat + mu
#      81             cov = self.H@Phat@(self.H.T) +self.R
#      82             print(mean, cov)
#
# ValueError: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 3 is different from 9)

# %%
test1d.plotResults()

# %% [markdown]
# Clearly, the model doesn't generalize well to multiple dimensions
